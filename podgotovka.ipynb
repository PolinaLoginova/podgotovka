# %% [markdown]
# ### Learning

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("data.xlsx")

# %%
df.head(1)
# Out:
#    1  2  3
# 0  4  5  6

# %%
df
# Out:
#                                                number_PP  justification  name  \
# 0      50, 101-0324, Кислород технический: газообразн...            NaN   NaN
# 1      51, 101-0797, Проволока горячекатаная в мотках...            NaN   NaN
# 2      52, 101-0857, Рубероид подкладочный с пылевидн...            NaN   NaN
# 3      53, 101-0962, Смазка солидол жировой марки «Ж»...            NaN   NaN
# 4      54, 101-1517, Электроды диаметром: 4 мм Э50, т...            NaN   NaN
# 5      55, 101-1529, Электроды диаметром: 6 мм Э42, т...            NaN   NaN
# 6      56, 101-1602, Ацетилен газообразный технически...            NaN   NaN
# 7      57, 101-1805, Гвозди строительные, т, , 12389,...            NaN   NaN
# 8      58, 102-0058, Доски обрезные хвойных пород дли...            NaN   NaN
# 9      59, 102-0062, Доски обрезные хвойных пород дли...            NaN   NaN
# 10     60, 102-0120, Доски обрезные хвойных пород дли...            NaN   NaN
# ...

# %%
df.tail(1)
# Out:
#    1  2  3
# 1  7  8  9

# %%
df.loc[df[2]==8] = np.nan

# %%
df.iloc[0,0]
# Out:
# '50, 101-0324, Кислород технический: газообразный, м3, 23366,963, 6,41, , , 149782,24, 11233668, , , , Нет, , , , 100, п, 02262016-02-100-СМ-5754-0 демонтаж жб конструкций, лот 1, 0067.2017-03-301-КЖ1.СО-0001-0, '

# %%
df.fillna(2, inplace = True)

# %%
df
# Out:
#      1    2    3
# 0  4.0  5.0  6.0
# 1  2.0  2.0  2.0

# %%
df[1].describe()
# Out:
# count    2.000000
# mean     3.000000
# std      1.414214
# min      2.000000
# 25%      2.500000
# 50%      3.000000
# 75%      3.500000
# max      4.000000
# Name: 1, dtype: float64

# %%
df[1] = df[1].astype(int)

# %%
df
# Out:
#    1    2    3
# 0  4  5.0  6.0
# 1  2  2.0  2.0

# %%
df[1].unique()
# Out:
# array([4, 2])
